# %%
numbers = [15, 10, 8, 20, 5]
numbers.sort()
print(numbers)
# Out:
# [5, 8, 10, 15, 20]

# %%
names = ["Bob","Alice", "David", "Charlie",]
names.sort()
print(names)
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']

# %%
names.append("Eve")
print(names)
names.remove("Alice")
print(names)
print(names[1:3])
# Out:
# ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
# ['Bob', 'Charlie', 'David', 'Eve']
# ['Charlie', 'David']

# %%
for i in numbers:
    print(f"Price: ${i}")
    i=i*2
    i=i+10
print(numbers)
# Out:
# Price: $5
# Price: $8
# Price: $10
# Price: $15
# Price: $20
# [5, 8, 10, 15, 20]

# %%
name_dict = [{"name": "yahav", "value": "1234"}, {"name": "bob", "value": "5678"}]
print(name_dict)
name_dict.append({"name": "alice", "value": "9012"})
print(name_dict)
name_dict.extend([{"name": "david", "value": "3456"}, {"name": "charlie", "value": "7890"}])
print(name_dict)
# Out:
# [{'name': 'yahav', 'value': '1234'}, {'name': 'bob', 'value': '5678'}]
# [{'name': 'yahav', 'value': '1234'}, {'name': 'bob', 'value': '5678'}, {'name': 'alice', 'value': '9012'}]
# [{'name': 'yahav', 'value': '1234'}, {'name': 'bob', 'value': '5678'}, {'name': 'alice', 'value': '9012'}, {'name': 'david', 'value': '3456'}, {'name': 'charlie', 'value': '7890'}]

# %%
users = {"yossi": 1234}

users["dana"] = 5678
users["ariel"] = 9012

# Output: 1234
print(users["yossi"])
print(users.values())
# Out:
# 1234
# dict_values([1234, 5678, 9012])
