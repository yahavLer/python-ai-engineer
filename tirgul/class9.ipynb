# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# # תרגול 9
#
#
#
# התרגול בונה pipeline:
#
# ```text
# Movie descriptions
# → BoW / TF-IDF
# → PMI / LDA / SVD semantic space
# → PyTorch tensors
# → semantic similarity
# ```
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 0. Setup
#
# </div>

# %%
# Core
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Scikit-learn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 1. קורפוס סרטים
#
# כל שורה היא **Document** אחד — תיאור קצר של סרט.
#
# העמודה `genre` תשמש אותנו רק לצביעה ובדיקה.
# אנחנו לא משתמשים בה כ־target לאימון supervised model.
#
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

movies = [
    {
        "title": "Space Rescue",
        "genre": "sci-fi",
        "text": "astronaut space mission planet rescue alien signal spaceship galaxy"
    },
    {
        "title": "Robot City",
        "genre": "sci-fi",
        "text": "robot artificial intelligence city future technology machine human"
    },
    {
        "title": "Galaxy War",
        "genre": "sci-fi",
        "text": "space galaxy war spaceship alien empire planet battle"
    },
    {
        "title": "Love in Paris",
        "genre": "romance",
        "text": "love paris relationship couple romance dinner music heart"
    },
    {
        "title": "Wedding Letters",
        "genre": "romance",
        "text": "wedding love letters family relationship romance heart"
    },
    {
        "title": "Summer Promise",
        "genre": "romance",
        "text": "summer beach love promise couple family memories"
    },
    {
        "title": "Detective Night",
        "genre": "crime",
        "text": "detective murder mystery police investigation suspect crime"
    },
    {
        "title": "Bank Heist",
        "genre": "crime",
        "text": "bank robbery police chase crime thief investigation plan"
    },
    {
        "title": "Hidden Evidence",
        "genre": "crime",
        "text": "evidence detective suspect trial murder police mystery"
    },
    {
        "title": "Dragon Kingdom",
        "genre": "fantasy",
        "text": "dragon kingdom magic sword hero castle battle prophecy"
    },
    {
        "title": "Wizard School",
        "genre": "fantasy",
        "text": "wizard magic school spell student prophecy castle"
    },
    {
        "title": "Forest Quest",
        "genre": "fantasy",
        "text": "hero forest quest magic sword kingdom creature"
    }
]

df = pd.DataFrame(movies)
df
# Out:
#               title    genre  \
# 0      Space Rescue   sci-fi
# 1        Robot City   sci-fi
# 2        Galaxy War   sci-fi
# 3     Love in Paris  romance
# 4   Wedding Letters  romance
# 5    Summer Promise  romance
# 6   Detective Night    crime
# 7        Bank Heist    crime
# 8   Hidden Evidence    crime
# 9    Dragon Kingdom  fantasy
# 10    Wizard School  fantasy
# 11     Forest Quest  fantasy
#
#                                                  text
# 0   astronaut space mission planet rescue alien si...
# 1   robot artificial intelligence city future tech...
# 2   space galaxy war spaceship alien empire planet...
# 3   love paris relationship couple romance dinner ...
# 4   wedding love letters family relationship roman...
# 5    summer beach love promise couple family memories
# 6   detective murder mystery police investigation ...
# 7   bank robbery police chase crime thief investig...
# 8   evidence detective suspect trial murder police...
# 9   dragon kingdom magic sword hero castle battle ...
# 10  wizard magic school spell student prophecy castle
# 11     hero forest quest magic sword kingdom creature

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 1 — הבנת הקורפוס
#
# ענו בקצרה:
#
# 1. מהו ה־Corpus?
#
# כל ה data set שלנו
#
# 2. מהו Document?
#
# שורה אחת בתוך ה corpus או תיאור אחד של סרט
#
# 3. מהו Token?
#
# מילה בתוך התיאור של הסרט
#
# 4. מהו Vocabulary?
#
# כל המילים היוחודיות, שהן לא חוזרות פעמיים
#
# 5. האם `genre` הוא target?
#
# לא, הוא רק lable . אנחנו בלמידה לא מונחית ואנחנו לא נותנים target למודל שלנו
#
# 6. האם אנחנו מאמנים supervised model?
#
# לא
#
# </div>

# %%
# TODO:
print(df.shape)
print(df.head())
print(df["genre"].value_counts())
# Out:
# (12, 3)
#              title    genre                                               text
# 0     Space Rescue   sci-fi  astronaut space mission planet rescue alien si...
# 1       Robot City   sci-fi  robot artificial intelligence city future tech...
# 2       Galaxy War   sci-fi  space galaxy war spaceship alien empire planet...
# 3    Love in Paris  romance  love paris relationship couple romance dinner ...
# 4  Wedding Letters  romance  wedding love letters family relationship roman...
# genre
# sci-fi     3
# romance    3
# crime      3
# fantasy    3
# Name: count, dtype: int64

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# df.shape
# df.head()
# df["genre"].value_counts()
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 2. EDA קצר
#
# נבדוק כמה מילים יש בכל תיאור וכמה סרטים יש מכל genre.
#
# </div>

# %%
df["n_words"] = df["text"].str.split().str.len()
df[["title", "genre", "n_words"]]
# Out:
#               title    genre  n_words
# 0      Space Rescue   sci-fi        9
# 1        Robot City   sci-fi        8
# 2        Galaxy War   sci-fi        8
# 3     Love in Paris  romance        8
# 4   Wedding Letters  romance        7
# 5    Summer Promise  romance        7
# 6   Detective Night    crime        7
# 7        Bank Heist    crime        8
# 8   Hidden Evidence    crime        7
# 9    Dragon Kingdom  fantasy        8
# 10    Wizard School  fantasy        7
# 11     Forest Quest  fantasy        7

# %%
df["genre"].value_counts().plot(kind="bar")
plt.ylabel("Number of movies")
plt.title("Movies per Genre")
plt.show()

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 2 — שאלות EDA
#
# ענו:
#
# 1. האם הקורפוס מאוזן מבחינת genres?
#
#  כן
#
# 2. האם כל המסמכים באורך דומה?
#
# כן
#
# 3. למה קורפוס קטן כזה טוב לתרגול?
#
# הוא מאשפר לנו לראות את התוצאות בצורה ויזואלית נוחה.
#
# 4. למה קורפוס קטן כזה בעייתי למחקר אמיתי?
#
# הופך ללא אמין
#
# </div>

# %%
# TODO:
# כתבו תשובות קצרות במרקדאון או בהערות קוד.

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# df["genre"].value_counts()
# df[["title", "genre", "n_words"]].sort_values("n_words", ascending=False)
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 3. Bag of Words
#
# נתחיל מייצוג פשוט: ספירת מילים.
#
# </div>

# %%
vec = CountVectorizer()
X_bow = vec.fit_transform(df["text"])
terms = vec.get_feature_names_out()

dtm = pd.DataFrame(
    X_bow.toarray(),
    columns=terms,
    index=df["title"]
)

dtm.head()
# Out:
#                  alien  artificial  astronaut  bank  battle  beach  castle  \
# title
# Space Rescue         1           0          1     0       0      0       0
# Robot City           0           1          0     0       0      0       0
# Galaxy War           1           0          0     0       1      0       0
# Love in Paris        0           0          0     0       0      0       0
# Wedding Letters      0           0          0     0       0      0       0
#
#                  chase  city  couple  ...  student  summer  suspect  sword  \
# title                                 ...
# Space Rescue         0     0       0  ...        0       0        0      0
# Robot City           0     1       0  ...        0       0        0      0
# Galaxy War           0     0       0  ...        0       0        0      0
# Love in Paris        0     0       1  ...        0       0        0      0
# Wedding Letters      0     0       0  ...        0       0        0      0
#
#                  technology  thief  trial  war  wedding  wizard
# title
# Space Rescue              0      0      0    0        0       0
# Robot City                1      0      0    0        0       0
# Galaxy War                0      0      0    1        0       0
# Love in Paris             0      0      0    0        0       0
# Wedding Letters           0      0      0    0        1       0
#
# [5 rows x 63 columns]

# %% [markdown]
# קיימות 63 מילים יחודיות, יש 12 סרטים.

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 3 — מילים נפוצות
#
# חשבו את 15 המילים הכי נפוצות בקורפוס והציגו אותן ב־Bar Plot.
#
# </div>

# %%
term_counts = np.asarray(X_bow.sum(axis=0)).ravel()

top_terms = pd.DataFrame({
    "term": terms,
    "count": term_counts
}).sort_values("count", ascending=False)

display(top_terms.head(15))

top_terms.head(15).plot(x="term", y="count", kind="bar", legend=False)
plt.ylabel("Count")
plt.title("Top Terms")
plt.show()
# Out:
#              term  count
# 39         police      3
# 30          magic      3
# 28           love      3
# 17         family      2
# 38         planet      2
# 41       prophecy      2
# 35        mystery      2
# 43   relationship      2
# 33         murder      2
# 47        romance      2
# 26        kingdom      2
# 25  investigation      2
# 22           hero      2
# 21          heart      2
# 50          space      2

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# term_counts = np.asarray(X_bow.sum(axis=0)).ravel()
#
# top_terms = pd.DataFrame({
#     "term": terms,
#     "count": term_counts
# }).sort_values("count", ascending=False)
#
# display(top_terms.head(15))
#
# top_terms.head(15).plot(x="term", y="count", kind="bar", legend=False)
# plt.ylabel("Count")
# plt.title("Top Terms")
# plt.show()
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 4. PMI / PPMI — מילים שמופיעות יחד
#
# PMI עוזר לזהות צמדי מילים שמופיעים יחד יותר ממה שהיינו מצפים במקרה.
#
# נחשב co-occurrence ברמת מסמך: שתי מילים מופיעות יחד אם הן מופיעות באותו מסמך.
#
# נמצא עבור כל צירוף מילים בכמה מסמכים הן מופיעות יחד
#
# </div>

# %%
# space + 
# detective murder

# love + paris

# %%
X_bin = (X_bow.toarray() > 0).astype(int) 

cooc = X_bin.T @ X_bin #vector muliple 
cooc_df = pd.DataFrame(cooc, index=terms, columns=terms)

cooc_df.head()
# Out:
#             alien  artificial  astronaut  bank  battle  beach  castle  chase  \
# alien           2           0          1     0       1      0       0      0
# artificial      0           1          0     0       0      0       0      0
# astronaut       1           0          1     0       0      0       0      0
# bank            0           0          0     1       0      0       0      1
# battle          1           0          0     0       2      0       1      0
#
#             city  couple  ...  student  summer  suspect  sword  technology  \
# alien          0       0  ...        0       0        0      0           0
# artificial     1       0  ...        0       0        0      0           1
# astronaut      0       0  ...        0       0        0      0           0
# bank           0       0  ...        0       0        0      0           0
# battle         0       0  ...        0       0        0      1           0
#
#             thief  trial  war  wedding  wizard
# alien           0      0    1        0       0
# artificial      0      0    0        0       0
# astronaut       0      0    0        0       0
# bank            1      0    0        0       0
# battle          0      0    1        0       0
#
# [5 rows x 63 columns]

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 4 — חישוב PPMI
#
# השלימו את חישוב ה־PMI וה־PPMI, ואז הציגו את 15 צמדי המילים עם הציון הגבוה ביותר.
#
# </div>

# %%
# PMI(x, y) = log(P(X,Y)/P(x)P(y))
## PPMI(x, y) = PMI(x,y)> 0

# %%
# TODO:
total_docs = X_bin.shape[0]

word_prob = X_bin.sum(axis=0) / total_docs
cooc_prob = cooc / total_docs

pmi = np.zeros_like(cooc_prob, dtype=float)

for i in range(len(terms)):
    for j in range(len(terms)):
        if cooc_prob[i, j] > 0:
            pmi[i, j] = np.log2(cooc_prob[i, j] / (word_prob[i] * word_prob[j]))
        else:
            pmi[i, j] = 0

ppmi = np.maximum(pmi, 0)

pairs = []

for i in range(len(terms)):
    for j in range(i + 1, len(terms)):
        pairs.append({
            "term_1": terms[i],
            "term_2": terms[j],
            "ppmi": ppmi[i, j]
        })

ppmi_pairs = pd.DataFrame(pairs).sort_values("ppmi", ascending=False)

ppmi_pairs.head(15)
# Out:
#             term_1        term_2      ppmi
# 1504       mission        signal  3.584963
# 106     artificial         robot  3.584963
# 450          chase       robbery  3.584963
# 442          chase          plan  3.584963
# 1419       machine    technology  3.584963
# 1233  intelligence         robot  3.584963
# 1907         spell        wizard  3.584963
# 1713       promise        summer  3.584963
# 488           city       machine  3.584963
# 1244  intelligence    technology  3.584963
# 1898         spell       student  3.584963
# 1178         human       machine  3.584963
# 1861        school        wizard  3.584963
# 1010        future         human  3.584963
# 1011        future  intelligence  3.584963

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# total_docs = X_bin.shape[0]
#
# word_prob = X_bin.sum(axis=0) / total_docs
# cooc_prob = cooc / total_docs
#
# pmi = np.zeros_like(cooc_prob, dtype=float)
#
# for i in range(len(terms)):
#     for j in range(len(terms)):
#         if cooc_prob[i, j] > 0:
#             pmi[i, j] = np.log2(cooc_prob[i, j] / (word_prob[i] * word_prob[j]))
#         else:
#             pmi[i, j] = 0
#
# ppmi = np.maximum(pmi, 0)
#
# pairs = []
#
# for i in range(len(terms)):
#     for j in range(i + 1, len(terms)):
#         pairs.append({
#             "term_1": terms[i],
#             "term_2": terms[j],
#             "ppmi": ppmi[i, j]
#         })
#
# ppmi_pairs = pd.DataFrame(pairs).sort_values("ppmi", ascending=False)
#
# ppmi_pairs.head(15)
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## שאלות חשיבה על PMI
#
# ענו:
#
# 1. אילו צמדי מילים קיבלו PPMI גבוה?
# 2. האם הם מתאימים לז׳אנרים?
# 3. מה ההבדל בין מילה נפוצה לבין צמד מילים משמעותי?
# 4. איך זה מחבר אותנו לרעיון של GloVe?
#
# </div>

# %%
# TODO:
# כתבו תשובות קצרות.

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# ppmi_pairs.head(20)
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 5. TF-IDF ו־SVD / LSA
#
# נעבור מ־BoW ל־TF-IDF, ואז נשתמש ב־TruncatedSVD כדי לבנות מרחב סמנטי מוקטן.
#
# </div>

# %%
tfidf_vec = TfidfVectorizer()
X_tfidf = tfidf_vec.fit_transform(df["text"])

tfidf_terms = tfidf_vec.get_feature_names_out()

print("TF-IDF shape:", X_tfidf.shape)
print("Vocabulary size:", len(tfidf_terms))
# Out:
# TF-IDF shape: (12, 63)
# Vocabulary size: 63

# %%
svd = TruncatedSVD(n_components=2, random_state=42)
X_lsa_2d = svd.fit_transform(X_tfidf)

print("LSA shape:", X_lsa_2d.shape)
print("Explained variance ratio:", svd.explained_variance_ratio_)
# Out:
# LSA shape: (12, 2)
# Explained variance ratio: [0.13175447 0.09945063]

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 5 — ויזואליזציה של מרחב SVD
#
# ציירו את הסרטים במרחב דו־ממדי:
#
# - ציר X: רכיב SVD ראשון.
# - ציר Y: רכיב SVD שני.
# - צבע לפי `genre`.
# - הוסיפו שמות סרטים על הגרף.
#
# </div>

# %%
plt.figure(figsize=(10, 7))
for genre in df["genre"].unique():
    mask = df["genre"] == genre
    plt.scatter(
        X_lsa_2d[mask, 0],
        X_lsa_2d[mask, 1],
        label=genre
    )
for i, title in enumerate(df["title"]):
    plt.text(X_lsa_2d[i, 0], X_lsa_2d[i, 1], title, fontsize=8)
plt.xlabel("SVD component 1")
plt.ylabel("SVD component 2")
plt.title("Movies in LSA Semantic Space")
plt.legend()
plt.show()

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# plt.figure(figsize=(10, 7))
#
# for genre in df["genre"].unique():
#     mask = df["genre"] == genre
#     plt.scatter(
#         X_lsa_2d[mask, 0],
#         X_lsa_2d[mask, 1],
#         label=genre
#     )
#
# for i, title in enumerate(df["title"]):
#     plt.text(X_lsa_2d[i, 0], X_lsa_2d[i, 1], title, fontsize=8)
#
# plt.xlabel("SVD component 1")
# plt.ylabel("SVD component 2")
# plt.title("Movies in LSA Semantic Space")
# plt.legend()
# plt.show()
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 6 — פרשנות רכיבי SVD
#
# בדקו אילו מילים מקבלות משקל גבוה בכל רכיב SVD.
#
# </div>

# %%
# TODO:
components = svd.components_

for comp_idx, comp in enumerate(components):
    top_idx = np.argsort(comp)[-8:][::-1]
    print(f"\nComponent {comp_idx + 1}:")
    for idx in top_idx:
        print(tfidf_terms[idx], round(comp[idx], 3))
# Out:
# Component 1:
# police 0.404
# murder 0.367
# suspect 0.367
# mystery 0.367
# detective 0.367
# investigation 0.287
# crime 0.287
# trial 0.198
#
# Component 2:
# magic 0.377
# sword 0.317
# hero 0.317
# kingdom 0.317
# castle 0.284
# prophecy 0.284
# battle 0.256
# dragon 0.202

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# components = svd.components_
#
# for comp_idx, comp in enumerate(components):
#     top_idx = np.argsort(comp)[-8:][::-1]
#     print(f"\nComponent {comp_idx + 1}:")
#     for idx in top_idx:
#         print(tfidf_terms[idx], round(comp[idx], 3))
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 6. Semantic Search במרחב SVD
#
# נחפש סרטים לפי שאילתה, אבל נשווה במרחב SVD המוקטן.
#
# </div>

# %%
query = "alien spaceship and planet mission"

q_tfidf = tfidf_vec.transform([query])
q_lsa = svd.transform(q_tfidf)

scores = cosine_similarity(q_lsa, X_lsa_2d).ravel()

df.assign(score=scores).sort_values("score", ascending=False)[
    ["title", "genre", "text", "score"]
].head(5)
# Out:
#              title    genre  \
# 0     Space Rescue   sci-fi
# 2       Galaxy War   sci-fi
# 9   Dragon Kingdom  fantasy
# 10   Wizard School  fantasy
# 11    Forest Quest  fantasy
#
#                                                  text  score
# 0   astronaut space mission planet rescue alien si...    1.0
# 2   space galaxy war spaceship alien empire planet...    1.0
# 9   dragon kingdom magic sword hero castle battle ...    1.0
# 10  wizard magic school spell student prophecy castle    1.0
# 11     hero forest quest magic sword kingdom creature    1.0

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 7 — בדיקת שאילתות
#
# בדקו את השאילתות הבאות:
#
# ```python
# queries = [
#     "alien spaceship planet",
#     "love wedding couple",
#     "detective police murder",
#     "magic kingdom sword",
#     "robot artificial intelligence future"
# ]
# ```
#
# עבור כל שאילתה הציגו Top 3 תוצאות.
#
# </div>

# %%
# TODO:
queries = [
    "alien spaceship planet",
    "love wedding couple",
    "detective police murder",
    "magic kingdom sword",
    "robot artificial intelligence future"
]

for query in queries:
    q_tfidf = tfidf_vec.transform([query])
    q_lsa = svd.transform(q_tfidf)
    scores = cosine_similarity(q_lsa, X_lsa_2d).ravel()

    print("\nQuery:", query)
    display(
        df.assign(score=scores)
          .sort_values("score", ascending=False)
          [["title", "genre", "score"]]
          .head(3)
    )
# Out:
# Query: alien spaceship planet
#             title    genre  score
# 0    Space Rescue   sci-fi    1.0
# 2      Galaxy War   sci-fi    1.0
# 9  Dragon Kingdom  fantasy    1.0
# Query: love wedding couple
#              title    genre     score
# 4  Wedding Letters  romance  0.999669
# 3    Love in Paris  romance  0.999584
# 5   Summer Promise  romance  0.997638
# Query: detective police murder
#              title  genre  score
# 6  Detective Night  crime    1.0
# 7       Bank Heist  crime    1.0
# 8  Hidden Evidence  crime    1.0
# Query: magic kingdom sword
#             title    genre  score
# 0    Space Rescue   sci-fi    1.0
# 2      Galaxy War   sci-fi    1.0
# 9  Dragon Kingdom  fantasy    1.0
# Query: robot artificial intelligence future
#              title    genre         score
# 5   Summer Promise  romance  5.143784e-17
# 4  Wedding Letters  romance  4.659171e-17
# 3    Love in Paris  romance  4.642401e-17

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# queries = [
#     "alien spaceship planet",
#     "love wedding couple",
#     "detective police murder",
#     "magic kingdom sword",
#     "robot artificial intelligence future"
# ]
#
# for query in queries:
#     q_tfidf = tfidf_vec.transform([query])
#     q_lsa = svd.transform(q_tfidf)
#     scores = cosine_similarity(q_lsa, X_lsa_2d).ravel()
#
#     print("\nQuery:", query)
#     display(
#         df.assign(score=scores)
#           .sort_values("score", ascending=False)
#           [["title", "genre", "score"]]
#           .head(3)
#     )
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 7. LDA Topic Modeling
#
# LDA מניח שכל מסמך הוא תערובת של topics, וכל topic הוא התפלגות על מילים.
#
# </div>

# %%
count_vec = CountVectorizer()
X_counts = count_vec.fit_transform(df["text"])
count_terms = count_vec.get_feature_names_out()

lda = LatentDirichletAllocation(
    n_components=4,
    random_state=42,
    learning_method="batch"
)

doc_topic = lda.fit_transform(X_counts)

print("Document-topic matrix shape:", doc_topic.shape)
# Out:
# Document-topic matrix shape: (12, 4)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 8 — הצגת מילים מובילות בכל Topic
#
# הציגו לכל topic את 8 המילים עם המשקל הגבוה ביותר.
#
# </div>

# %%
# TODO:
for topic_idx, topic in enumerate(lda.components_):
    top_idx = topic.argsort()[-8:][::-1]
    top_words = [count_terms[i] for i in top_idx]
    print(f"Topic {topic_idx}: {top_words}")
# Out:
# Topic 0: ['police', 'murder', 'suspect', 'detective', 'mystery', 'crime', 'investigation', 'future']
# Topic 1: ['love', 'heart', 'relationship', 'romance', 'castle', 'prophecy', 'couple', 'magic']
# Topic 2: ['hero', 'sword', 'kingdom', 'battle', 'magic', 'dragon', 'thief', 'bank']
# Topic 3: ['alien', 'galaxy', 'planet', 'spaceship', 'space', 'family', 'love', 'signal']

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# for topic_idx, topic in enumerate(lda.components_):
#     top_idx = topic.argsort()[-8:][::-1]
#     top_words = [count_terms[i] for i in top_idx]
#     print(f"Topic {topic_idx}: {top_words}")
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 9 — Topic דומיננטי לכל סרט
#
# הוסיפו ל־DataFrame עמודה בשם `dominant_topic`.
#
# לאחר מכן השוו בין `genre` לבין `dominant_topic`.
#
# </div>

# %%
df["dominant_topic"] = doc_topic.argmax(axis=1)

display(df[["title", "genre", "dominant_topic"]])

pd.crosstab(df["dominant_topic"], df["genre"])
# Out:
#               title    genre  dominant_topic
# 0      Space Rescue   sci-fi               3
# 1        Robot City   sci-fi               0
# 2        Galaxy War   sci-fi               2
# 3     Love in Paris  romance               1
# 4   Wedding Letters  romance               2
# 5    Summer Promise  romance               3
# 6   Detective Night    crime               0
# 7        Bank Heist    crime               2
# 8   Hidden Evidence    crime               0
# 9    Dragon Kingdom  fantasy               2
# 10    Wizard School  fantasy               1
# 11     Forest Quest  fantasy               2
# genre           crime  fantasy  romance  sci-fi
# dominant_topic
# 0                   2        0        0       1
# 1                   0        1        1       0
# 2                   1        2        1       1
# 3                   0        0        1       1

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# df["dominant_topic"] = doc_topic.argmax(axis=1)
#
# display(df[["title", "genre", "dominant_topic"]])
#
# pd.crosstab(df["dominant_topic"], df["genre"])
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## שאלות השוואה — LDA מול SVD
#
# ענו:
#
# 1. האם topics של LDA דומים לז׳אנרים?
# 2. האם הם דומים לרכיבי SVD?
# 3. מה ההבדל בין component של SVD לבין topic של LDA?
# 4. האם כל מסמך חייב להשתייך ל־topic אחד בלבד?
# 5. למה LDA מתאים לפרשנות?
#
# </div>

# %%
# TODO:
# כתבו תשובות קצרות.

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# display(pd.crosstab(df["dominant_topic"], df["genre"]))
#
# components = svd.components_
# for comp_idx, comp in enumerate(components):
#     top_idx = np.argsort(comp)[-8:][::-1]
#     print(f"\nSVD Component {comp_idx + 1}:")
#     print([tfidf_terms[idx] for idx in top_idx])
#
# for topic_idx, topic in enumerate(lda.components_):
#     top_idx = topic.argsort()[-8:][::-1]
#     print(f"\nLDA Topic {topic_idx}:")
#     print([count_terms[i] for i in top_idx])
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 8. מעבר ל־PyTorch Tensors
#
# ניקח את הייצוגים הסמנטיים שקיבלנו מ־SVD ונמיר אותם ל־PyTorch Tensor.
#
# </div>

# %%
try:
    import torch
except ImportError as e:
    raise ImportError(
        "PyTorch is not installed in this environment. "
        "In Colab, run: !pip install torch"
    ) from e

if torch.cuda.is_available():
    device = "cuda"
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

device
# Out:
# 'mps'

# %%
X_tensor = torch.tensor(X_lsa_2d, dtype=torch.float32, device=device)

print("Tensor:")
print(X_tensor)
print("Shape:", X_tensor.shape)
print("Dtype:", X_tensor.dtype)
print("Device:", X_tensor.device)
print("Number of dimensions:", X_tensor.ndim)
# Out:
# Tensor:
# tensor([[ 1.5077e-15,  3.2194e-01],
#         [-1.4891e-16,  6.0111e-17],
#         [ 1.4653e-15,  4.0434e-01],
#         [-6.7355e-16,  5.2202e-15],
#         [-6.6561e-16,  5.0346e-15],
#         [-8.8603e-16,  3.8549e-15],
#         [ 9.2145e-01, -1.2161e-15],
#         [ 4.9743e-01, -4.2774e-16],
#         [ 8.3551e-01, -1.2094e-15],
#         [ 6.9068e-16,  8.2126e-01],
#         [ 4.6765e-16,  5.2247e-01],
#         [ 4.8248e-16,  6.6666e-01]], device='mps:0')
# Shape: torch.Size([12, 2])
# Dtype: torch.float32
# Device: mps:0
# Number of dimensions: 2

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 10 — Tensor Basics
#
# ענו:
#
# 1. מה ה־shape של `X_tensor`?
# 2. מה מייצגת כל שורה?
# 3. מה מייצגת כל עמודה?
# 4. למה `dtype=torch.float32` מתאים כאן?
# 5. מה ההבדל בין CPU, CUDA ו־MPS?
#
# </div>

# %%
# TODO:
# כתבו תשובות קצרות.

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# print("Shape:", X_tensor.shape)
# print("Dtype:", X_tensor.dtype)
# print("Device:", X_tensor.device)
# print("Number of dimensions:", X_tensor.ndim)
# print("First row:", X_tensor[0])
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## 9. Cosine Similarity ב־PyTorch
#
# נחשב מטריצת דמיון בין כל הסרטים בעזרת PyTorch.
#
# </div>

# %%
X_norm = X_tensor / X_tensor.norm(dim=1, keepdim=True)

similarity_matrix = X_norm @ X_norm.T

sim_df = pd.DataFrame(
    similarity_matrix.detach().cpu().numpy(),
    index=df["title"],
    columns=df["title"]
)

sim_df.round(2)
# Out:
# title            Space Rescue  Robot City  Galaxy War  Love in Paris  \
# title
# Space Rescue             1.00        0.37        1.00           0.99
# Robot City               0.37        1.00        0.37           0.49
# Galaxy War               1.00        0.37        1.00           0.99
# Love in Paris            0.99        0.49        0.99           1.00
# Wedding Letters          0.99        0.49        0.99           1.00
# Summer Promise           0.97        0.57        0.97           1.00
# Detective Night          0.00       -0.93        0.00          -0.13
# Bank Heist               0.00       -0.93        0.00          -0.13
# Hidden Evidence          0.00       -0.93        0.00          -0.13
# Dragon Kingdom           1.00        0.37        1.00           0.99
# Wizard School            1.00        0.37        1.00           0.99
# Forest Quest             1.00        0.37        1.00           0.99
#
# title            Wedding Letters  Summer Promise  Detective Night  Bank Heist  \
# title
# Space Rescue                0.99            0.97             0.00        0.00
# Robot City                  0.49            0.57            -0.93       -0.93
# Galaxy War                  0.99            0.97             0.00        0.00
# Love in Paris               1.00            1.00            -0.13       -0.13
# Wedding Letters             1.00            1.00            -0.13       -0.13
# Summer Promise              1.00            1.00            -0.22       -0.22
# Detective Night            -0.13           -0.22             1.00        1.00
# Bank Heist                 -0.13           -0.22             1.00        1.00
# Hidden Evidence            -0.13           -0.22             1.00        1.00
# Dragon Kingdom              0.99            0.97            -0.00       -0.00
# Wizard School               0.99            0.97            -0.00        0.00
# Forest Quest                0.99            0.97            -0.00       -0.00
#
# title            Hidden Evidence  Dragon Kingdom  Wizard School  Forest Quest
# title
# Space Rescue                0.00            1.00           1.00          1.00
# Robot City                 -0.93            0.37           0.37          0.37
# Galaxy War                  0.00            1.00           1.00          1.00
# Love in Paris              -0.13            0.99           0.99          0.99
# Wedding Letters            -0.13            0.99           0.99          0.99
# Summer Promise             -0.22            0.97           0.97          0.97
# Detective Night             1.00           -0.00          -0.00         -0.00
# Bank Heist                  1.00           -0.00           0.00         -0.00
# Hidden Evidence             1.00           -0.00          -0.00         -0.00
# Dragon Kingdom             -0.00            1.00           1.00          1.00
# Wizard School              -0.00            1.00           1.00          1.00
# Forest Quest               -0.00            1.00           1.00          1.00

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 11 — Heatmap של דמיון סרטים
#
# ציירו heatmap של מטריצת הדמיון.
#
# </div>

# %%
# TODO:
# plt.figure(figsize=(9, 8))
# plt.imshow(similarity_matrix.detach().cpu().numpy())
# plt.xticks(range(len(df)), df["title"], rotation=90)
# plt.yticks(range(len(df)), df["title"])
# plt.colorbar()
# plt.title("Movie Similarity Matrix")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# plt.figure(figsize=(9, 8))
# plt.imshow(similarity_matrix.detach().cpu().numpy())
# plt.xticks(range(len(df)), df["title"], rotation=90)
# plt.yticks(range(len(df)), df["title"])
# plt.colorbar()
# plt.title("Movie Similarity Matrix")
# plt.tight_layout()
# plt.show()
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## תרגיל 12 — פונקציה למציאת סרטים דומים
#
# כתבו פונקציה:
#
# ```python
# most_similar_movie(title, top_n=5)
# ```
#
# הפונקציה תקבל שם סרט ותחזיר את הסרטים הכי דומים לו לפי מטריצת הדמיון.
#
# </div>

# %%
# TODO:
# def most_similar_movie(title, top_n=5):
#     ...
#
# most_similar_movie("Space Rescue")

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# def most_similar_movie(title, top_n=5):
#     idx = df.index[df["title"] == title][0]
#
#     scores = similarity_matrix[idx].detach().cpu().numpy()
#
#     result = df[["title", "genre"]].copy()
#     result["score"] = scores
#
#     return result.sort_values("score", ascending=False).head(top_n)
#
# most_similar_movie("Space Rescue")
# ```
#
# </details>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
#
# ## שאלות סיכום
#
# ענו בקצרה:
#
# 1. מה ההבדל בין BoW, TF-IDF, SVD, LDA ו־GloVe?
# 2. מה SVD מוצא במטריצת TF-IDF?
# 3. למה קוראים לזה LSA / LSI?
# 4. מה LDA נותן ש־SVD לא נותן?
# 5. למה PyTorch Tensor מתאים לייצוג כזה?
# 6. האם השתמשנו כאן ב־Deep Learning אמיתי?
# 7. מה חסר כדי להפוך את זה לאימון רשת נוירונים?
# 8. מה הקשר בין co-occurrence לבין embeddings?
#
# </div>

# %% [markdown]
# <details dir="rtl">
# <summary>פתרון מוסתר</summary>
#
# ```python
# # Suggested checks for summary discussion:
# print("BoW shape:", X_bow.shape)
# print("TF-IDF shape:", X_tfidf.shape)
# print("SVD representation shape:", X_lsa_2d.shape)
# print("LDA document-topic shape:", doc_topic.shape)
# print("PyTorch tensor shape:", X_tensor.shape)
# print("Used supervised labels for fitting?", False)
# ```
#
# </details>
