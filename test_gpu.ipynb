# %%
import torch

# ── Basic Info ──────────────────────────────────────────
print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
print(f"MPS available   : {torch.backends.mps.is_available()}")

# ── Select best available device ────────────────────────
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU detected    : {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Apple Silicon GPU (MPS) detected")
else:
    device = torch.device("cpu")
    print("No GPU found – running on CPU")

print(f"\nUsing device    : {device}")

# ── Quick tensor test on device ─────────────────────────
x = torch.rand(1000, 1000).to(device)
y = torch.rand(1000, 1000).to(device)
z = x @ y  # matrix multiply on device
print(f"\n✅ Tensor multiply on {device} succeeded! Shape: {z.shape}")
# Out:
# PyTorch version : 2.10.0
# CUDA available  : False
# MPS available   : True
# Apple Silicon GPU (MPS) detected
#
# Using device    : mps
#
# ✅ Tensor multiply on mps succeeded! Shape: torch.Size([1000, 1000])
